# %% [markdown]
# <a href="https://colab.research.google.com/github/BenziJPCorrales/DATA-433-Indiana-Housing-Prediction/blob/main/housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

schools_df = pd.read_csv('Public_School_Locations_2021-2022.csv')

zhvi_df = pd.read_csv('State_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')

insthpi_df = pd.read_csv('INSTHPI.csv', parse_dates=['observation_date'])

# %%
print(schools_df.head())
print(zhvi_df.head())
print(insthpi_df.head())

print(schools_df.info())
print(zhvi_df.info())
print(insthpi_df.info())

print(schools_df.shape)
print(zhvi_df.shape)
print(insthpi_df.shape)
# Out:
#            X          Y  objectid       ncessch    leaid  \
# 0 -85.775905  39.969108         1  180000601935  1800006
# 1 -86.796069  41.640993         2  180000601943  1800006
# 2 -86.400610  40.741735         3  180000601946  1800006
# 3 -86.165005  39.768108         4  180000602453  1800006
# 4 -87.165505  39.034707         5  180000702265  1800007
#
#                                name  opstfips               street  \
# 0   Pendleton Juvenile Correctional        18         9310 S SR 67
# 1     LaPorte Juvenile Correctional        18         2407 N 500 W
# 2  Logansport Juvenile Correctional        18         1118 S SR 25
# 3  Dept of Correction Adult Schools        18  302 W Washington St
# 4   Greene-Sullivan Special Ed Coop        18           77 A St NE
#
#            city state  ...                            nmcbsa  cbsatype  csa  \
# 0     Pendleton    IN  ...  Indianapolis-Carmel-Anderson, IN         1  294
# ...

# %%
# Numerical summary
print(schools_df.describe())
print(zhvi_df.describe())
print(insthpi_df.describe())

# Check for missing values
print(schools_df.isna().sum())
print(zhvi_df.isna().sum())
print(insthpi_df.isna().sum())
# Out:
#                  X            Y     objectid       ncessch         leaid  \
# count  1933.000000  1933.000000  1933.000000  1.933000e+03  1.933000e+03
# mean    -86.253133    40.116534   967.000000  1.805977e+11  1.805977e+06
# std       0.737276     1.062726   558.153354  4.018670e+08  4.018667e+03
# min     -87.908005    37.881107     1.000000  1.800006e+11  1.800006e+06
# 25%     -86.859400    39.506008   484.000000  1.802850e+11  1.802850e+06
# 50%     -86.156605    39.955808   967.000000  1.805460e+11  1.805460e+06
# 75%     -85.773505    41.106108  1450.000000  1.809600e+11  1.809600e+06
# max     -84.815105    41.756408  1933.000000  1.813230e+11  1.813230e+06
#
#        opstfips           zip   stfip          cnty       locale          lat  \
# count    1933.0   1933.000000  1933.0   1933.000000  1933.000000  1933.000000
# mean       18.0  46782.989653    18.0  18088.193999    27.382307    40.116526
# ...

# %%
import matplotlib.pyplot as plt
insthpi_df.plot(x='observation_date', y='INSTHPI', title='Indiana House Price Index Over Time', figsize=(12,6))
# Out:
# <Axes: title={'center': 'Indiana House Price Index Over Time'}, xlabel='observation_date'>

# %%
# Histogram of house prices
zhvi_df_indiana['ZHVI'].hist(bins=30, figsize=(8,5))
plt.title('Distribution of Indiana ZHVI')
# Out:
# Text(0.5, 1.0, 'Distribution of Indiana ZHVI')

# %%
plt.figure(figsize=(12, 6))
schools_by_county.head(10).plot(kind='bar')
plt.title('Top 10 Counties by Number of Schools in Indiana')
plt.xlabel('County FIPS Code')
plt.ylabel('Number of Schools')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
